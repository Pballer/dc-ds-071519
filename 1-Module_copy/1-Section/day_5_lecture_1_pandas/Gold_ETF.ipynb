# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('/Users/flatironschool/Downloads/nugt_dust_all.csv')

# %%
df.dtypes
# Out:
# PERMNO       int64
# date         int64
# TICKER      object
# COMNAM      object
# BIDLO      float64
# ASKHI      float64
# PRC        float64
# VOL          int64
# BID        float64
# ASK        float64
# OPENPRC    float64
# dtype: object

# %%
df.head(2)
# Out:
#    PERMNO      date TICKER                       COMNAM  BIDLO  ASKHI    PRC  \
# 0   12442  20101208   DUST  DIREXION SHARES E T F TRUST  40.18  42.02  41.64
# 1   12442  20101209   DUST  DIREXION SHARES E T F TRUST  40.69  41.71  41.16
#
#       VOL    BID    ASK  OPENPRC
# 0  187700  41.57  41.59    40.48
# 1  358000  41.16  41.18    40.72

# %%
df[(df.TICKER == 'DUST') & (df.date > 20170401)]
# Out:
#       PERMNO      date TICKER                       COMNAM    BIDLO    ASKHI  \
# 1589   12442  20170403   DUST  DIREXION SHARES E T F TRUST  29.3200  31.0800
# 1590   12442  20170404   DUST  DIREXION SHARES E T F TRUST  28.4100  29.4100
# 1591   12442  20170405   DUST  DIREXION SHARES E T F TRUST  27.6704  29.9800
# 1592   12442  20170406   DUST  DIREXION SHARES E T F TRUST  28.0800  29.1800
# 1593   12442  20170407   DUST  DIREXION SHARES E T F TRUST  26.4000  29.2400
# 1594   12442  20170410   DUST  DIREXION SHARES E T F TRUST  27.5000  29.3200
# 1595   12442  20170411   DUST  DIREXION SHARES E T F TRUST  24.9500  26.9308
# 1596   12442  20170412   DUST  DIREXION SHARES E T F TRUST  24.6900  26.1000
# 1597   12442  20170413   DUST  DIREXION SHARES E T F TRUST  23.6600  25.1390
# 1598   12442  20170417   DUST  DIREXION SHARES E T F TRUST  24.0200  25.3700
# 1599   12442  20170418   DUST  DIREXION SHARES E T F TRUST  24.9800  26.3100
# ...

# %%
df[(df.TICKER == 'DUST') & ((df.date > 20170401) & (df.date < 20170431))].plot.line(x='date', y='PRC', figsize=(20,4))

# %%
df[(df.TICKER == 'NUGT') & ((df.date > 20170401) & (df.date < 20170431))].plot.line(x='date', y='PRC', figsize=(20,4))
